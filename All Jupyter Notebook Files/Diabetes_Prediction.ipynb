# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, f1_score, confusion_matrix

# %% [markdown]
# Importing the Data **Set**

# %%
df = pd.read_csv('/content/diabetes-dataset.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %% [markdown]
# ## **Data Preprocessing**

# %%
df.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# min       0.000000                  0.078000    21.000000     0.000000
# 25%      27.375000                  0.244000    24.000000     0.000000
# 50%      32.300000                  0.376000    29.000000     0.000000
# 75%      36.800000                  0.624000    40.000000     1.000000
# max      80.600000                  2.420000    81.000000     1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8630172632526190006 = autoviz.get_df('df_8630172632526190006')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8630172632526190006, *['Pregnancies'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8630172632526190006 = autoviz.get_df('df_8630172632526190006')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8630172632526190006, *['Glucose'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8630172632526190006 = autoviz.get_df('df_8630172632526190006')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8630172632526190006, *['BloodPressure'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8630172632526190006 = autoviz.get_df('df_8630172632526190006')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8630172632526190006, *['SkinThickness'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8630172632526190006 = autoviz.get_df('df_8630172632526190006')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8630172632526190006, *['Pregnancies'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8630172632526190006 = autoviz.get_df('df_8630172632526190006')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8630172632526190006, *['Glucose'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8630172632526190006 = autoviz.get_df('df_8630172632526190006')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8630172632526190006, *['BloodPressure'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8630172632526190006 = autoviz.get_df('df_8630172632526190006')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8630172632526190006, *['SkinThickness'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8630172632526190006 = autoviz.get_df('df_8630172632526190006')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_8630172632526190006, *[[['Pregnancies', 'Glucose'], ['Glucose', 'BloodPressure'], ['BloodPressure', 'SkinThickness'], ['SkinThickness', 'Insulin']]], **{})
# chart

# %%
df.shape
# Out:
# (2000, 9)

# %% [markdown]
# # Checking the NULL Values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.120405       0.149672      -0.063375
# Glucose                      0.120405  1.000000       0.138044       0.062368
# BloodPressure                0.149672  0.138044       1.000000       0.198800
# SkinThickness               -0.063375  0.062368       0.198800       1.000000
# Insulin                     -0.076600  0.320371       0.087384       0.448859
# BMI                          0.019475  0.226864       0.281545       0.393760
# DiabetesPedigreeFunction    -0.025453  0.123243       0.051331       0.178299
# Age                          0.539457  0.254496       0.238375      -0.111034
# Outcome                      0.224437  0.458421       0.075958       0.076040
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.076600  0.019475                 -0.025453
# Glucose                   0.320371  0.226864                  0.123243
# BloodPressure             0.087384  0.281545                  0.051331
# SkinThickness             0.448859  0.393760                  0.178299
# Insulin                   1.000000  0.223012                  0.192719
# BMI                       0.223012  1.000000                  0.125719
# DiabetesPedigreeFunction  0.192719  0.125719                  1.000000
# Age                      -0.085879  0.038987                  0.026569
# Outcome                   0.120924  0.276726                  0.155459
#
#                                Age   Outcome
# Pregnancies               0.539457  0.224437
# Glucose                   0.254496  0.458421
# BloodPressure             0.238375  0.075958
# SkinThickness            -0.111034  0.076040
# Insulin                  -0.085879  0.120924
# BMI                       0.038987  0.276726
# DiabetesPedigreeFunction  0.026569  0.155459
# Age                       1.000000  0.236509
# Outcome                   0.236509  1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2343919544830548057 = autoviz.get_df('df_2343919544830548057')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2343919544830548057, *['Pregnancies'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2343919544830548057 = autoviz.get_df('df_2343919544830548057')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2343919544830548057, *['Glucose'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2343919544830548057 = autoviz.get_df('df_2343919544830548057')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2343919544830548057, *['BloodPressure'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2343919544830548057 = autoviz.get_df('df_2343919544830548057')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2343919544830548057, *['SkinThickness'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2343919544830548057 = autoviz.get_df('df_2343919544830548057')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2343919544830548057, *['Pregnancies'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2343919544830548057 = autoviz.get_df('df_2343919544830548057')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2343919544830548057, *['Glucose'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2343919544830548057 = autoviz.get_df('df_2343919544830548057')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2343919544830548057, *['BloodPressure'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2343919544830548057 = autoviz.get_df('df_2343919544830548057')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2343919544830548057, *['SkinThickness'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2343919544830548057 = autoviz.get_df('df_2343919544830548057')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_2343919544830548057, *[[['Pregnancies', 'Glucose'], ['Glucose', 'BloodPressure'], ['BloodPressure', 'SkinThickness'], ['SkinThickness', 'Insulin']]], **{})
# chart

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %%
df.isnull()
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0           False    False          False          False    False  False
# 1           False    False          False          False    False  False
# 2           False    False          False          False    False  False
# 3           False    False          False          False    False  False
# 4           False    False          False          False    False  False
# ...           ...      ...            ...            ...      ...    ...
# 1995        False    False          False          False    False  False
# 1996        False    False          False          False    False  False
# 1997        False    False          False          False    False  False
# 1998        False    False          False          False    False  False
# 1999        False    False          False          False    False  False
#
#       DiabetesPedigreeFunction    Age  Outcome
# 0                        False  False    False
# 1                        False  False    False
# 2                        False  False    False
# 3                        False  False    False
# 4                        False  False    False
# ...                        ...    ...      ...
# 1995                     False  False    False
# 1996                     False  False    False
# 1997                     False  False    False
# 1998                     False  False    False
# 1999                     False  False    False
#
# [2000 rows x 9 columns]

# %%
df.isnull().sum().reset_index().rename(columns = ({'index':'Columns' , '0':'Total NULL Values'}))
# Out:
#                     Columns  0
# 0               Pregnancies  0
# 1                   Glucose  0
# 2             BloodPressure  0
# 3             SkinThickness  0
# 4                   Insulin  0
# 5                       BMI  0
# 6  DiabetesPedigreeFunction  0
# 7                       Age  0
# 8                   Outcome  0

# %%
df['Outcome'].value_counts()
# Out:
# 0    1316
# 1     684
# Name: Outcome, dtype: int64

# %% [markdown]
# Here,
# 1. 1 -> Person is Diabetic
# 2. 0 -> Person is not Diabetic

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness    Insulin  \
# Outcome
# 0           3.168693  110.586626      68.094985      20.052432  70.563830
# 1           4.732456  141.568713      71.166667      22.633041  98.897661
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.567477                  0.434676  31.081307
# 1        35.320468                  0.540681  36.956140
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8766002035013178188, *['Pregnancies'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8766002035013178188, *['Glucose'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8766002035013178188, *['BloodPressure'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8766002035013178188, *['SkinThickness'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8766002035013178188, *['Pregnancies'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8766002035013178188, *['Glucose'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8766002035013178188, *['BloodPressure'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8766002035013178188, *['SkinThickness'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_8766002035013178188, *[[['Pregnancies', 'Glucose'], ['Glucose', 'BloodPressure'], ['BloodPressure', 'SkinThickness'], ['SkinThickness', 'Insulin']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_8766002035013178188, *['Pregnancies', 'count()', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_8766002035013178188, *['Glucose', 'count()', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_8766002035013178188, *['BloodPressure', 'count()', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8766002035013178188 = autoviz.get_df('df_8766002035013178188')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_8766002035013178188, *['SkinThickness', 'count()', None], **{})
# chart

# %% [markdown]
# ##  Splitting the Data for training.

# %%
X = df.drop(columns = 'Outcome' , axis = 1)
Y = df['Outcome']

# %%
X.shape
# Out:
# (2000, 8)

# %%
Y.shape
# Out:
# (2000,)

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size = 0.2 , random_state = 20)

# %%
print('Training Data : ' , X_train.shape , Y_train.shape)
print('Testing Data : ' , X_test.shape , Y_test.shape)
# Out:
# Training Data :  (1600, 8) (1600,)
# Testing Data :  (400, 8) (400,)

# %% [markdown]
# ## **Time to Train Our Model.**
# 1. Here We will try to train our model using all possible algorithms that comes under classificatino category and will try to figure it out that which algorithm gives us the best accuracy.
# 2. Then after we will save that best trained model for deployment process.

# %% [markdown]
# ## **1. Logistic Regression Algorithm.**

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(penalty='l2',       # L2 regularization (default)
    C=1.0,              # Regularization strength (default)
    solver='lbfgs',     # Optimization algorithm (default)
    max_iter=100,       # Maximum number of iterations (default)
    multi_class='auto', # Auto choose one-vs-rest or multinomial (default)
    class_weight=None,  # No class weights (default)
    random_state=42,    # Random seed for reproducibility
    fit_intercept=True, # Calculate the intercept (default)
    intercept_scaling=1 # No scaling of the intercept (default))
)

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, y_pred)

# %%
print("Accuracy :", accuracy * 100)
print("Classification Report:\n", classification_report(Y_test, y_pred))
# Out:
# Accuracy : 74.25
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82       270
#            1       0.64      0.47      0.54       130
#
#     accuracy                           0.74       400
#    macro avg       0.71      0.67      0.68       400
# weighted avg       0.73      0.74      0.73       400

# %% [markdown]
#  So here by using LogisticRegression Algorithm we got around 74.25% Accuracy.

# %% [markdown]
# ## **2. Decision Tree Algorithm**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(
    criterion='gini',          # Gini impurity (default)
    splitter='best',           # Choose the best split (default)
    max_depth=None,            # No maximum depth (default)
    min_samples_split=2,       # Minimum samples to split (default)
    min_samples_leaf=1,        # Minimum samples in a leaf (default)
    max_features=None,         # Consider all features (default)
    class_weight=None,         # No class weights (default)
    random_state=42            # Random seed for reproducibility)
)

# %%
classifier.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = classifier.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, y_pred)
class_report = classification_report(Y_test, y_pred)

# %%
print("Accuracy :", accuracy * 100)
print("Classification Report:\n", class_report)
# Out:
# Accuracy : 98.75
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       270
#            1       0.98      0.98      0.98       130
#
#     accuracy                           0.99       400
#    macro avg       0.98      0.99      0.99       400
# weighted avg       0.99      0.99      0.99       400

# %% [markdown]
# Here , DecisionTreeClassifier Algorithm Trains well with our dataset and gives Around 99% Accuracy.

# %% [markdown]
# ## **3. Random Forest Classifier Algorithm**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Random_forest_model = RandomForestClassifier(
    n_estimators=100,          # Number of trees in the forest
    criterion='gini',          # Gini impurity (default)
    max_depth=None,            # No maximum depth (default)
    min_samples_split=2,       # Minimum samples to split (default)
    min_samples_leaf=1,        # Minimum samples in a leaf (default)
    max_features='auto',       # Auto choose features to consider
    class_weight=None,         # No class weights (default)
    random_state=42            # Random seed for reproducibility
)

# %%
Random_forest_model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(max_features='auto', random_state=42)

# %%
y_pred = Random_forest_model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, y_pred)
class_report = classification_report(Y_test, y_pred)

# %%
print("Accuracy :", accuracy * 100)
print("Classification Report:\n", class_report)
# Out:
# Accuracy : 97.5
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       270
#            1       0.98      0.95      0.96       130
#
#     accuracy                           0.97       400
#    macro avg       0.98      0.97      0.97       400
# weighted avg       0.98      0.97      0.97       400

# %% [markdown]
# Here , RandomForestClassifier Algorithm Trains well with our dataset and gives Around 97.5% Accuracy.

# %% [markdown]
# ## **Support Vector Machine(SVM) Algorithm**

# %%
from sklearn.svm import SVC

# %%
SVM_model = SVC(
    kernel='rbf',            # Radial Basis Function (RBF) kernel (default)
    C=1.0,                   # Regularization parameter (default)
    gamma='scale',           # Kernel coefficient (default)
    class_weight=None,       # No class weights (default)
    random_state=42          # Random seed for reproducibility
)

# %%
SVM_model.fit(X_train, Y_train)
# Out:
# SVC(random_state=42)

# %%
y_pred = SVM_model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, y_pred)
class_report = classification_report(Y_test, y_pred)

# %%
print("Accuracy :", accuracy * 100)
print("Classification Report:\n", class_report)
# Out:
# Accuracy : 75.5
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83       270
#            1       0.69      0.45      0.55       130
#
#     accuracy                           0.76       400
#    macro avg       0.73      0.68      0.69       400
# weighted avg       0.75      0.76      0.74       400

# %% [markdown]
#  So here by using Support Vector Machine Algorithm we got around 75.5% Accuracy which is a bit similar to Logistic Regression Algorithm.

# %% [markdown]
# ## **Naive Bayes Algorithm**

# %%
from sklearn.naive_bayes import GaussianNB

# %%
custom_priors = [0.7, 0.3]  # Let's assume class 0 has a prior probability of 0.7, and class 1 has a prior probability of 0.3

# %%
Guassian_model = GaussianNB(priors=custom_priors)

# %%
Guassian_model.fit(X_train, Y_train)
# Out:
# GaussianNB(priors=[0.7, 0.3])

# %%
y_pred = Guassian_model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, y_pred)
class_report = classification_report(Y_test, y_pred)

# %%
print("Accuracy :", accuracy * 100)
print("Classification Report:\n", class_report)
# Out:
# Accuracy : 75.25
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83       270
#            1       0.65      0.52      0.58       130
#
#     accuracy                           0.75       400
#    macro avg       0.72      0.69      0.70       400
# weighted avg       0.74      0.75      0.74       400

# %% [markdown]
# So here by using Naive Bayes Algorithm we got around 75.25% Accuracy which is a bit similar to Logistic Regression Algorithm and SVM Algorithm.

# %% [markdown]
#  **Conclusion :** Decision Tree Algorithm and Random Forest Algorithm Trains well with our provided data. So here we are going to use **Decision Tree Algotrithm** as it is giving us around 99% Accuracy.

# %% [markdown]
# ## **Time to Save Our Decision Tree Model.**

# %%
import pickle

# %%
with open('Diabetes_model.pkl', 'wb') as file:
    pickle.dump(classifier, file)
